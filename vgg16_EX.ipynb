# %% [markdown]
# <a href="https://colab.research.google.com/github/IR04dy/NN/blob/main/vgg16_EX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

# %%
image = load_img('/content/bmw.jpg', target_size=(224,224))
image = img_to_array(image)

image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image = preprocess_input(image)

model = VGG16()

yhat = model.predict(image)
label = decode_predictions(yhat)

label = label[0][0]

print('%s (%.2f%%' % (label[1], label[2]*100))
from IPython.display import  Image
Image('/content/bmw.jpg')
Image('/content/bmw.jpg', width=224, height=224)
# Out:
# 1/1 [==============================] - 1s 645ms/step
# sports_car (42.41%
